# %% [markdown]
# #### Importing libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# #### Importing the dataset

# %%
data = pd.read_csv('osmi2014.csv')

# %% [markdown]
# #### Exploring the data

# %%
data.head()
# Out:
#              Timestamp  Age  Gender         Country state self_employed  \
# 0  2014-08-27 11:29:31   37  Female   United States    IL           NaN
# 1  2014-08-27 11:29:37   44       M   United States    IN           NaN
# 2  2014-08-27 11:29:44   32    Male          Canada   NaN           NaN
# 3  2014-08-27 11:29:46   31    Male  United Kingdom   NaN           NaN
# 4  2014-08-27 11:30:22   31    Male   United States    TX           NaN
#
#   family_history treatment work_interfere    no_employees  ...  \
# 0             No       Yes          Often            6-25  ...
# 1             No        No         Rarely  More than 1000  ...
# 2             No        No         Rarely            6-25  ...
# 3            Yes       Yes          Often          26-100  ...
# 4             No        No          Never         100-500  ...
#
#                 leave mental_health_consequence phys_health_consequence  \
# 0       Somewhat easy                        No                      No
# ...

# %%
# age is numerical, every other is categorical
data.dtypes
# Out:
# Timestamp                    object
# Age                           int64
# Gender                       object
# Country                      object
# state                        object
# self_employed                object
# family_history               object
# treatment                    object
# work_interfere               object
# no_employees                 object
# remote_work                  object
# tech_company                 object
# benefits                     object
# care_options                 object
# wellness_program             object
# seek_help                    object
# anonymity                    object
# leave                        object
# mental_health_consequence    object
# phys_health_consequence      object
# coworkers                    object
# supervisor                   object
# mental_health_interview      object
# phys_health_interview        object
# mental_vs_physical           object
# obs_consequence              object
# ...

# %%
# finding the null values
data.isnull().sum()
# Out:
# Timestamp                       0
# Age                             0
# Gender                          0
# Country                         0
# state                         515
# self_employed                  18
# family_history                  0
# treatment                       0
# work_interfere                264
# no_employees                    0
# remote_work                     0
# tech_company                    0
# benefits                        0
# care_options                    0
# wellness_program                0
# seek_help                       0
# anonymity                       0
# leave                           0
# mental_health_consequence       0
# phys_health_consequence         0
# coworkers                       0
# supervisor                      0
# mental_health_interview         0
# phys_health_interview           0
# mental_vs_physical              0
# obs_consequence                 0
# comments                     1095
# dtype: int64

# %% [markdown]
# #### Drop irrelevant columns

# %%
data.drop(columns=['state','comments', 'Timestamp'], inplace=True)

# %% [markdown]
# ##### Rename columns

# %%
data.rename(columns = {'Age': 'age'}, inplace=True)
data.rename(columns = {'Gender': 'gender'}, inplace=True)
data.rename(columns = {'Country': 'country'}, inplace=True)

# %%
data.head()
# Out:
#    age  gender         country self_employed family_history treatment  \
# 0   37  Female   United States           NaN             No       Yes
# 1   44       M   United States           NaN             No        No
# 2   32    Male          Canada           NaN             No        No
# 3   31    Male  United Kingdom           NaN            Yes       Yes
# 4   31    Male   United States           NaN             No        No
#
#   work_interfere    no_employees remote_work tech_company  ...   anonymity  \
# 0          Often            6-25          No          Yes  ...         Yes
# 1         Rarely  More than 1000          No           No  ...  Don't know
# 2         Rarely            6-25          No          Yes  ...  Don't know
# 3          Often          26-100          No          Yes  ...          No
# 4          Never         100-500         Yes          Yes  ...  Don't know
#
#                 leave mental_health_consequence phys_health_consequence  \
# ...

# %% [markdown]
# ##### Impute NaN (self_employed = 18, work_interfere = 264)

# %%
print(data['self_employed'].value_counts())
print(data['work_interfere'].value_counts())
# Out:
# self_employed
# No     1095
# Yes     146
# Name: count, dtype: int64
# work_interfere
# Sometimes    465
# Never        213
# Rarely       173
# Often        144
# Name: count, dtype: int64

# %%
data['self_employed'].fillna('No', inplace=True)
data['work_interfere'].fillna('Never', inplace=True)

# %%
data.head()
# Out:
#    age  gender         country self_employed family_history treatment  \
# 0   37  Female   United States            No             No       Yes
# 1   44       M   United States            No             No        No
# 2   32    Male          Canada            No             No        No
# 3   31    Male  United Kingdom            No            Yes       Yes
# 4   31    Male   United States            No             No        No
#
#   work_interfere    no_employees remote_work tech_company  ...   anonymity  \
# 0          Often            6-25          No          Yes  ...         Yes
# 1         Rarely  More than 1000          No           No  ...  Don't know
# 2         Rarely            6-25          No          Yes  ...  Don't know
# 3          Often          26-100          No          Yes  ...          No
# 4          Never         100-500         Yes          Yes  ...  Don't know
#
#                 leave mental_health_consequence phys_health_consequence  \
# ...

# %% [markdown]
# ##### Correction of Outliers

# %%
data['age'].unique()
# Out:
# array([         37,          44,          32,          31,          33,
#                 35,          39,          42,          23,          29,
#                 36,          27,          46,          41,          34,
#                 30,          40,          38,          50,          24,
#                 18,          28,          26,          22,          19,
#                 25,          45,          21,         -29,          43,
#                 56,          60,          54,         329,          55,
#        99999999999,          48,          20,          57,          58,
#                 47,          62,          51,          65,          49,
#              -1726,           5,          53,          61,           8,
#                 11,          -1,          72], dtype=int64)

# %%
# drop 'age' outliers
data.drop(data[data['age'] < 18].index, inplace = True) 
data.drop(data[data['age'] > 99].index, inplace = True)

# %%
data['age'].unique()
# Out:
# array([37, 44, 32, 31, 33, 35, 39, 42, 23, 29, 36, 27, 46, 41, 34, 30, 40,
#        38, 50, 24, 18, 28, 26, 22, 19, 25, 45, 21, 43, 56, 60, 54, 55, 48,
#        20, 57, 58, 47, 62, 51, 65, 49, 53, 61, 72], dtype=int64)

# %%
data['gender'].unique()
# Out:
# array(['Female', 'M', 'Male', 'male', 'female', 'm', 'Male-ish', 'maile',
#        'Trans-female', 'Cis Female', 'F', 'something kinda male?',
#        'Cis Male', 'Woman', 'f', 'Mal', 'Male (CIS)', 'queer/she/they',
#        'non-binary', 'Femake', 'woman', 'Make', 'Nah', 'Enby', 'fluid',
#        'Genderqueer', 'Female ', 'Androgyne', 'Agender',
#        'cis-female/femme', 'Guy (-ish) ^_^', 'male leaning androgynous',
#        'Male ', 'Man', 'Trans woman', 'msle', 'Neuter', 'Female (trans)',
#        'queer', 'Female (cis)', 'Mail', 'cis male', 'Malr', 'femail',
#        'Cis Man', 'ostensibly male, unsure what that really means'],
#       dtype=object)

# %%
# drop 'gender' outliers
data['gender'].replace(['M', 'Male', 'male', 'm', 'Male-ish', 'maile', 'Cis Male', 'Mal', 'Male (CIS)', 'Make', 'Male ', 'Man', 'msle', 'Mail', 'cis male', 'Malr', 'Cis Man'], 'Male', inplace=True)
data['gender'].replace(['Female', 'female', 'Cis Female', 'F', 'Woman', 'f', 'Femake', 'woman', 'Female ', 'cis-female/femme', 'Female (cis)', 'femail'], 'Female', inplace=True)
data['gender'].replace(['Trans-female', 'something kinda male?', 'queer/she/they', 'non-binary', 'Nah', 'Enby', 'fluid',
       'Genderqueer', 'Androgyne', 'Agender', 'Guy (-ish) ^_^', 'male leaning androgynous', 'Trans woman', 'Neuter', 'Female (trans)', 'queer', 'ostensibly male, unsure what that really means'], 'Other', inplace=True)

# %%
data['gender'].unique()
# Out:
# array(['Female', 'Male', 'Other'], dtype=object)

# %%
data
# Out:
#       age  gender         country self_employed family_history treatment  \
# 0      37  Female   United States            No             No       Yes
# 1      44    Male   United States            No             No        No
# 2      32    Male          Canada            No             No        No
# 3      31    Male  United Kingdom            No            Yes       Yes
# 4      31    Male   United States            No             No        No
# ...   ...     ...             ...           ...            ...       ...
# 1254   26    Male  United Kingdom            No             No       Yes
# 1255   32    Male   United States            No            Yes       Yes
# 1256   34    Male   United States            No            Yes       Yes
# 1257   46  Female   United States            No             No        No
# 1258   25    Male   United States            No            Yes       Yes
#
#      work_interfere    no_employees remote_work tech_company  ...   anonymity  \
# ...

# %% [markdown]
# #### Saving the cleaned dataset

# %%
cleaned_data = data
cleaned_data.to_csv('C:/Users/Benji/python_learn/portfolio/cleaned_data.csv', index=False)
